# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = {
    'Student_ID': [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    'Gender': ['Female', 'Male', 'Female', 'Male', 'Female',
               'Male', 'Female', 'Male', 'Female', 'Male'],
    'Age': [20, 21, 20, 22, 21, 20, 22, 21, 20, 22],
    'Study_Hours': [3, 5, 2, 6, 4, 7, 3, 5, 4, 6],
    'Attendance': [85, 90, 78, 95, 88, 92, 80, 89, 84, 94],
    'Previous_Score': [70, 80, 65, 85, 75, 88, 68, 82, 73, 86],
    'Final_Score': [75, 85, 68, 90, 80, 92, 72, 87, 78, 91]
}

df = pd.DataFrame(data)

df
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance  Previous_Score  \
# 0         101  Female   20            3          85              70
# 1         102    Male   21            5          90              80
# 2         103  Female   20            2          78              65
# 3         104    Male   22            6          95              85
# 4         105  Female   21            4          88              75
# 5         106    Male   20            7          92              88
# 6         107  Female   22            3          80              68
# 7         108    Male   21            5          89              82
# 8         109  Female   20            4          84              73
# 9         110    Male   22            6          94              86
#
#    Final_Score
# 0           75
# 1           85
# 2           68
# 3           90
# 4           80
# 5           92
# 6           72
# 7           87
# 8           78
# 9           91

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#    Student_ID  Gender  Age  Study_Hours  Attendance  Previous_Score  \
# 0         101  Female   20            3          85              70
# 1         102    Male   21            5          90              80
# 2         103  Female   20            2          78              65
# 3         104    Male   22            6          95              85
# 4         105  Female   21            4          88              75
# 5         106    Male   20            7          92              88
# 6         107  Female   22            3          80              68
# 7         108    Male   21            5          89              82
# 8         109  Female   20            4          84              73
# 9         110    Male   22            6          94              86
#
#    Final_Score
# 0           75
# 1           85
# 2           68
# 3           90
# 4           80
# 5           92
# 6           72
# 7           87
# 8           78
# 9           91

# %%
df.shape
# Out:
# (10, 7)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Gender', 'Age', 'Study_Hours', 'Attendance',
#        'Previous_Score', 'Final_Score'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Student_ID         int64
# Gender            object
# Age                int64
# Study_Hours        int64
# Attendance         int64
# Previous_Score     int64
# Final_Score        int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Student_ID      10 non-null     int64
#  1   Gender          10 non-null     object
#  2   Age             10 non-null     int64
#  3   Study_Hours     10 non-null     int64
#  4   Attendance      10 non-null     int64
#  5   Previous_Score  10 non-null     int64
#  6   Final_Score     10 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 692.0+ bytes

# %%
df.describe()
# Out:
#        Student_ID        Age  Study_Hours  Attendance  Previous_Score  \
# count    10.00000  10.000000    10.000000   10.000000       10.000000
# mean    105.50000  20.900000     4.500000   87.500000       77.200000
# std       3.02765   0.875595     1.581139    5.700877        8.121303
# min     101.00000  20.000000     2.000000   78.000000       65.000000
# 25%     103.25000  20.000000     3.250000   84.250000       70.750000
# 50%     105.50000  21.000000     4.500000   88.500000       77.500000
# 75%     107.75000  21.750000     5.750000   91.500000       84.250000
# max     110.00000  22.000000     7.000000   95.000000       88.000000
#
#        Final_Score
# count    10.000000
# mean     81.800000
# std       8.456424
# min      68.000000
# 25%      75.750000
# 50%      82.500000
# 75%      89.250000
# max      92.000000

# %%
df.isnull().sum()
# Out:
# Student_ID        0
# Gender            0
# Age               0
# Study_Hours       0
# Attendance        0
# Previous_Score    0
# Final_Score       0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    5
# Male      5
# Name: count, dtype: int64

# %%
df['Study_Hours'].describe()
# Out:
# count    10.000000
# mean      4.500000
# std       1.581139
# min       2.000000
# 25%       3.250000
# 50%       4.500000
# 75%       5.750000
# max       7.000000
# Name: Study_Hours, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['Study_Hours'], df['Final_Score'])

plt.xlabel('Study Hours')
plt.ylabel('Final Score')
plt.title('Study Hours vs Final Score')

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.scatter(df['Attendance'], df['Final_Score'])

plt.xlabel('Attendance (%)')
plt.ylabel('Final Score')
plt.title('Attendance vs Final Score')

plt.show()

# %%
plt.figure(figsize=(8,5))

plt.hist(df['Final_Score'], bins=5)

plt.xlabel('Final Score')
plt.ylabel('Number of Students')
plt.title('Distribution of Final Scores')

plt.show()

# %%
df.groupby('Gender')['Final_Score'].mean()
# Out:
# Gender
# Female    74.6
# Male      89.0
# Name: Final_Score, dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                 Student_ID       Age  Study_Hours  Attendance  Previous_Score  \
# Student_ID        1.000000  0.314347     0.336550    0.170591        0.320837
# Age               0.314347  1.000000     0.280900    0.389539        0.315631
# Study_Hours       0.336550  0.280900     1.000000    0.918337        0.986431
# Attendance        0.170591  0.389539     0.918337    1.000000        0.947954
# Previous_Score    0.320837  0.315631     0.986431    0.947954        1.000000
# Final_Score       0.321142  0.327133     0.980579    0.961092        0.997258
#
#                 Final_Score
# Student_ID         0.321142
# Age                0.327133
# Study_Hours        0.980579
# Attendance         0.961092
# Previous_Score     0.997258
# Final_Score        1.000000

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    df.corr(numeric_only=True),
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(y=df['Final_Score'])

plt.title('Final Score Box Plot')
plt.ylabel('Final Score')

plt.show()
